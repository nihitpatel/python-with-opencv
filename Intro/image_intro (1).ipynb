# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('2.jpg')
img2 = img[:,:,::-1]
plt.imshow(img2)
plt.show()
img3 = cv2.resize(img2,(28,28))
plt.imshow(img3)
plt.show()

arr = np.array(img3)
flat_arr = arr.ravel()
flat_arr
# Out:
# array([ 78, 157,  42, ..., 104, 145,  59], dtype=uint8)

# %%
img = cv2.imread('2.jpg')

plt.subplot(231)
plt.imshow(img)
plt.show()

plt.subplot(231)
#b,g,r = cv2.split(img)
#img2 = cv2.merge([r,g,b])
img2 = img[:,:,::-1]
plt.imshow(img2)
cv2.imwrite('new dog.jpg',img2);
plt.title('DOG')
plt.show()

# %%
px = img[99,99]
print(px)
# Out:
# [146 205 254]

# %%
blue = img[50,50,1]
print(blue)
# Out:
# 156

# %%
print(img.shape)
print(img.size)
print(img.dtype)
# Out:
# (288, 374, 3)
# 323136
# uint8

# %%
ball = img[50:150,200:300]
img[150:250,50:150] = [0,0,0]
plt.imshow(img)
plt.show()

# %%
img2 = cv2.imread('3.jpg')
img3 = cv2.add(img,img2)
plt.imshow(img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-44-ebb990ef45c0> in <module>()
#       1 img2 = cv2.imread('3.jpg')
# ----> 2 img3 = cv2.add(img,img2)
#       3 plt.imshow(img3)
#       4 plt.show()
#
# error: D:\Build\OpenCV\opencv-3.2.0\modules\core\src\arithm.cpp:659: error: (-209) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function cv::arithm_op
